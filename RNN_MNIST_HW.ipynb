# %% [markdown]
# <a href="https://colab.research.google.com/github/Shj-A/2022_ML_Project/blob/main/RNN_MNIST_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
import copy

# you have to set mini-batch size as a hyperparameter
# batch size : how many samples per batch to load
batch_size = 32

train_data = torchvision.datasets.MNIST(
    root = './data/MNIST',
    train = True,
    download = True,
    transform = transforms.Compose([transforms.ToTensor()])
)

test_data = torchvision.datasets.MNIST(
    root = './data/MNIST',
    train = False,
    download = True,
    transform = transforms.Compose([transforms.ToTensor()])
)

train_data, valid_data = train_test_split(train_data, test_size=0.2, shuffle=True)
print('# of train data : {}'.format(len(train_data)))
print('# of valid data : {}'.format(len(valid_data)))
print('# of test data : {}'.format(len(test_data)))

train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size = batch_size, shuffle = False)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size, shuffle = False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/MNIST/raw
#
# # of train data : 48000
# # of valid data : 12000
# # of test data : 10000

# %%
from torch.nn.modules.dropout import Dropout
import torch.nn as nn

class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, n_outputs, sequence_len):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size * sequence_len, n_outputs)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        x, _ = self.lstm(x, (h0, c0))
        x = x.reshape(x.shape[0], -1)
        x = self.fc(x)

        return x

class GRU(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, n_outputs, sequence_len):
        super(GRU, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size * sequence_len, n_outputs)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        x, _ = self.gru(x, h0)
        x = x.reshape(x.shape[0], -1)
        x = self.fc(x)

        return x

# %%
input_size = 28
sequence_len = 28
num_layers = 2
hidden_size = 64
n_outputs = 10

learning_rate = 0.01

model = LSTM(input_size, hidden_size, num_layers, n_outputs, sequence_len)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
loss_function = nn.CrossEntropyLoss()

# %% [markdown]
# # 3-2 Change the number of hidden layers

# %%
import copy

hidden_layer = [2,5,10]

for item in hidden_layer:
    num_layers = item
    model = LSTM(input_size, hidden_size, num_layers, n_outputs, sequence_len)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    loss_function = nn.CrossEntropyLoss()
    
    print("hiddenlayer :", item,"\n",model)
    for i in range(0,3):
        n_epochs = 5
        train_loss = [] # train loss per epoch
        valid_loss = [] # valid loss per epoch
        
        train_acc = [] # train accuracy per epoch
        valid_acc = [] # valid accuracy per epoch
        
        # update following two variables whenever valid accuracy improves
        best_acc = 0
        best_model = copy.deepcopy(model)
        
        for epoch in range(n_epochs):
            model.train() # set model as training mode(for compute gradient)
            train_total = 0
            train_correct = 0
            epoch_train_loss = 0
            for i, data in enumerate(train_loader):
                optimizer.zero_grad()
                
                inputs, labels = data[0], data[1]
                outputs = model(inputs.squeeze(1))
                _, predicted = torch.max(outputs.data, 1)
                train_total += labels.size(0)
                train_correct += (predicted == labels).sum().item()
                
                loss = loss_function(outputs, labels)
                epoch_train_loss += loss.item()
                
                loss.backward() # compute gradient
                optimizer.step() # update weight & bias in the model with computed gradient
                
            train_loss.append(epoch_train_loss/len(train_loader))
            train_acc.append(train_correct/train_total)
            
            model.eval() # set model as evaluation mode
            with torch.no_grad():
                valid_total = 0
                valid_correct = 0
                epoch_valid_loss = 0
                for data in valid_loader:
                    inputs, labels = data[0], data[1]
                    outputs = model(inputs.squeeze(1))
                    
                    _, predicted = torch.max(outputs.data, 1)
                    valid_total += labels.size(0)
                    valid_correct += (predicted == labels).sum().item()
                    
                    loss = loss_function(outputs, labels)
                    epoch_valid_loss += loss.item()
                
                valid_loss.append(epoch_valid_loss/len(valid_loader))
                valid_acc.append(valid_correct / valid_total)
                
            print('[{}/{}]'.format(epoch+1, n_epochs))
            print('training loss : {:.3f}\t training accuracy : {:.3f}'.format(epoch_train_loss/len(train_loader), train_correct/train_total))
            print('validation loss : {:.3f}\t validation accuracy : {:.3f}'.format(epoch_valid_loss/len(valid_loader), valid_correct/valid_total))
            
            if valid_correct/valid_total > best_acc:
                print('validation accuracy improved {:.5f} ======> {:.5f}'.format(best_acc, valid_correct/valid_total))
                best_acc = valid_correct/valid_total
                best_model = copy.deepcopy(model)
        
        best_model.eval()
        with torch.no_grad():
            test_total = 0
            test_correct = 0
            for data in test_loader:
                inputs, labels = data[0], data[1]
                outputs = best_model(inputs.squeeze(1))
                
                _, predicted = torch.max(outputs.data, 1)
                test_total += labels.size(0)
                test_correct += (predicted == labels).sum().item()
                
            test_acc = test_correct / test_total
            print('test accuracy : {:.3f}'.format(test_acc))    
        print("----------------------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# hiddenlayer : 2
#  LSTM(
#   (lstm): LSTM(28, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.171	 training accuracy : 0.947
# validation loss : 0.090	 validation accuracy : 0.975
# validation accuracy improved 0.00000 ======> 0.97525
# [2/5]
# training loss : 0.070	 training accuracy : 0.979
# validation loss : 0.064	 validation accuracy : 0.982
# validation accuracy improved 0.97525 ======> 0.98217
# [3/5]
# training loss : 0.057	 training accuracy : 0.983
# validation loss : 0.080	 validation accuracy : 0.979
# [4/5]
# training loss : 0.050	 training accuracy : 0.984
# validation loss : 0.062	 validation accuracy : 0.982
# [5/5]
# training loss : 0.041	 training accuracy : 0.987
# validation loss : 0.075	 validation accuracy : 0.980
# test accuracy : 0.981
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.039	 training accuracy : 0.987
# validation loss : 0.079	 validation accuracy : 0.980
# validation accuracy improved 0.00000 ======> 0.98000
# [2/5]
# training loss : 0.034	 training accuracy : 0.989
# validation loss : 0.077	 validation accuracy : 0.980
# validation accuracy improved 0.98000 ======> 0.98017
# [3/5]
# training loss : 0.031	 training accuracy : 0.991
# validation loss : 0.091	 validation accuracy : 0.979
# [4/5]
# training loss : 0.032	 training accuracy : 0.989
# validation loss : 0.080	 validation accuracy : 0.982
# validation accuracy improved 0.98017 ======> 0.98192
# [5/5]
# training loss : 0.028	 training accuracy : 0.991
# validation loss : 0.085	 validation accuracy : 0.981
# test accuracy : 0.984
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.029	 training accuracy : 0.991
# validation loss : 0.078	 validation accuracy : 0.982
# validation accuracy improved 0.00000 ======> 0.98200
# [2/5]
# training loss : 0.029	 training accuracy : 0.991
# validation loss : 0.089	 validation accuracy : 0.980
# [3/5]
# training loss : 0.026	 training accuracy : 0.991
# validation loss : 0.086	 validation accuracy : 0.980
# [4/5]
# training loss : 0.024	 training accuracy : 0.992
# validation loss : 0.081	 validation accuracy : 0.984
# validation accuracy improved 0.98200 ======> 0.98417
# [5/5]
# training loss : 0.023	 training accuracy : 0.992
# validation loss : 0.085	 validation accuracy : 0.981
# test accuracy : 0.984
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# hiddenlayer : 5
#  LSTM(
#   (lstm): LSTM(28, 64, num_layers=5, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.293	 training accuracy : 0.904
# validation loss : 0.107	 validation accuracy : 0.969
# validation accuracy improved 0.00000 ======> 0.96850
# [2/5]
# training loss : 0.107	 training accuracy : 0.966
# validation loss : 0.122	 validation accuracy : 0.965
# [3/5]
# training loss : 0.081	 training accuracy : 0.975
# validation loss : 0.093	 validation accuracy : 0.975
# validation accuracy improved 0.96850 ======> 0.97450
# [4/5]
# training loss : 0.073	 training accuracy : 0.977
# validation loss : 0.086	 validation accuracy : 0.975
# validation accuracy improved 0.97450 ======> 0.97508
# [5/5]
# training loss : 0.066	 training accuracy : 0.980
# validation loss : 0.094	 validation accuracy : 0.971
# test accuracy : 0.978
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.062	 training accuracy : 0.980
# validation loss : 0.082	 validation accuracy : 0.976
# validation accuracy improved 0.00000 ======> 0.97617
# [2/5]
# training loss : 0.055	 training accuracy : 0.983
# validation loss : 0.084	 validation accuracy : 0.976
# [3/5]
# training loss : 0.056	 training accuracy : 0.983
# validation loss : 0.076	 validation accuracy : 0.978
# validation accuracy improved 0.97617 ======> 0.97825
# [4/5]
# training loss : 0.054	 training accuracy : 0.983
# validation loss : 0.082	 validation accuracy : 0.978
# [5/5]
# training loss : 0.051	 training accuracy : 0.984
# validation loss : 0.076	 validation accuracy : 0.977
# test accuracy : 0.981
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.048	 training accuracy : 0.984
# validation loss : 0.076	 validation accuracy : 0.979
# validation accuracy improved 0.00000 ======> 0.97875
# [2/5]
# training loss : 0.048	 training accuracy : 0.985
# validation loss : 0.076	 validation accuracy : 0.981
# validation accuracy improved 0.97875 ======> 0.98142
# [3/5]
# training loss : 0.049	 training accuracy : 0.984
# validation loss : 0.077	 validation accuracy : 0.978
# [4/5]
# training loss : 0.045	 training accuracy : 0.985
# validation loss : 0.072	 validation accuracy : 0.981
# [5/5]
# training loss : 0.047	 training accuracy : 0.984
# validation loss : 0.077	 validation accuracy : 0.978
# test accuracy : 0.982
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# hiddenlayer : 10
#  LSTM(
#   (lstm): LSTM(28, 64, num_layers=10, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 2.303	 training accuracy : 0.107
# validation loss : 2.303	 validation accuracy : 0.113
# validation accuracy improved 0.00000 ======> 0.11342
# [2/5]
# training loss : 2.302	 training accuracy : 0.108
# validation loss : 2.303	 validation accuracy : 0.113
# [3/5]
# training loss : 2.302	 training accuracy : 0.109
# validation loss : 2.303	 validation accuracy : 0.113
# [4/5]
# training loss : 2.303	 training accuracy : 0.108
# validation loss : 2.302	 validation accuracy : 0.105
# [5/5]
# training loss : 2.302	 training accuracy : 0.110
# validation loss : 2.303	 validation accuracy : 0.113
# test accuracy : 0.114
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.303	 training accuracy : 0.109
# validation loss : 2.302	 validation accuracy : 0.113
# validation accuracy improved 0.00000 ======> 0.11342
# [2/5]
# training loss : 2.303	 training accuracy : 0.108
# validation loss : 2.302	 validation accuracy : 0.113
# [3/5]
# training loss : 2.302	 training accuracy : 0.111
# validation loss : 2.302	 validation accuracy : 0.113
# [4/5]
# training loss : 2.303	 training accuracy : 0.110
# validation loss : 2.302	 validation accuracy : 0.113
# [5/5]
# training loss : 2.303	 training accuracy : 0.109
# validation loss : 2.303	 validation accuracy : 0.113
# test accuracy : 0.114
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.303	 training accuracy : 0.108
# validation loss : 2.302	 validation accuracy : 0.098
# validation accuracy improved 0.00000 ======> 0.09792
# [2/5]
# training loss : 2.302	 training accuracy : 0.108
# validation loss : 2.302	 validation accuracy : 0.113
# validation accuracy improved 0.09792 ======> 0.11342
# [3/5]
# training loss : 2.303	 training accuracy : 0.110
# validation loss : 2.303	 validation accuracy : 0.101
# [4/5]
# training loss : 2.303	 training accuracy : 0.109
# validation loss : 2.302	 validation accuracy : 0.113
# [5/5]
# training loss : 2.303	 training accuracy : 0.108
# validation loss : 2.302	 validation accuracy : 0.113
# test accuracy : 0.114
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3-3 Change optimization

# %%
optimizer_list= [torch.optim.Adagrad(model.parameters(), lr = learning_rate), 
                 torch.optim.RMSprop(model.parameters(), lr = learning_rate),
                 torch.optim.Adadelta(model.parameters(), lr = learning_rate)]

for item in optimizer_list:
    num_layers = 2
    model = LSTM(input_size, hidden_size, num_layers, n_outputs, sequence_len)
    optimizer = item
    loss_function = nn.CrossEntropyLoss()
    
    print("optimizer :", item,"\n",model)
    for i in range(0,3):
        n_epochs = 5
        train_loss = [] # train loss per epoch
        valid_loss = [] # valid loss per epoch
        
        train_acc = [] # train accuracy per epoch
        valid_acc = [] # valid accuracy per epoch
        
        # update following two variables whenever valid accuracy improves
        best_acc = 0
        best_model = copy.deepcopy(model)
        
        for epoch in range(n_epochs):
            model.train() # set model as training mode(for compute gradient)
            train_total = 0
            train_correct = 0
            epoch_train_loss = 0
            for i, data in enumerate(train_loader):
                optimizer.zero_grad()
                
                inputs, labels = data[0], data[1]
                outputs = model(inputs.squeeze(1))
                _, predicted = torch.max(outputs.data, 1)
                train_total += labels.size(0)
                train_correct += (predicted == labels).sum().item()
                
                loss = loss_function(outputs, labels)
                epoch_train_loss += loss.item()
                
                loss.backward() # compute gradient
                optimizer.step() # update weight & bias in the model with computed gradient
                
            train_loss.append(epoch_train_loss/len(train_loader))
            train_acc.append(train_correct/train_total)
            
            model.eval() # set model as evaluation mode
            with torch.no_grad():
                valid_total = 0
                valid_correct = 0
                epoch_valid_loss = 0
                for data in valid_loader:
                    inputs, labels = data[0], data[1]
                    outputs = model(inputs.squeeze(1))
                    
                    _, predicted = torch.max(outputs.data, 1)
                    valid_total += labels.size(0)
                    valid_correct += (predicted == labels).sum().item()
                    
                    loss = loss_function(outputs, labels)
                    epoch_valid_loss += loss.item()
                
                valid_loss.append(epoch_valid_loss/len(valid_loader))
                valid_acc.append(valid_correct / valid_total)
                
            print('[{}/{}]'.format(epoch+1, n_epochs))
            print('training loss : {:.3f}\t training accuracy : {:.3f}'.format(epoch_train_loss/len(train_loader), train_correct/train_total))
            print('validation loss : {:.3f}\t validation accuracy : {:.3f}'.format(epoch_valid_loss/len(valid_loader), valid_correct/valid_total))
            
            if valid_correct/valid_total > best_acc:
                print('validation accuracy improved {:.5f} ======> {:.5f}'.format(best_acc, valid_correct/valid_total))
                best_acc = valid_correct/valid_total
                best_model = copy.deepcopy(model)
        
        best_model.eval()
        with torch.no_grad():
            test_total = 0
            test_correct = 0
            for data in test_loader:
                inputs, labels = data[0], data[1]
                outputs = best_model(inputs.squeeze(1))
                
                _, predicted = torch.max(outputs.data, 1)
                test_total += labels.size(0)
                test_correct += (predicted == labels).sum().item()
                
            test_acc = test_correct / test_total
            print('test accuracy : {:.3f}'.format(test_acc))    
        print("----------------------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# optimizer : Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.01
#     lr_decay: 0
#     weight_decay: 0
# )
#  LSTM(
#   (lstm): LSTM(28, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# validation accuracy improved 0.00000 ======> 0.10517
# [2/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [3/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [4/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [5/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# test accuracy : 0.101
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# validation accuracy improved 0.00000 ======> 0.10517
# [2/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [3/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [4/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [5/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# test accuracy : 0.101
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# validation accuracy improved 0.00000 ======> 0.10517
# [2/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [3/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [4/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# [5/5]
# training loss : 2.305	 training accuracy : 0.102
# validation loss : 2.305	 validation accuracy : 0.105
# test accuracy : 0.101
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# optimizer : RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 0.01
#     momentum: 0
#     weight_decay: 0
# )
#  LSTM(
#   (lstm): LSTM(28, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# validation accuracy improved 0.00000 ======> 0.10508
# [2/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [3/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [4/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [5/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# test accuracy : 0.101
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# validation accuracy improved 0.00000 ======> 0.10508
# [2/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [3/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [4/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [5/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# test accuracy : 0.101
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# validation accuracy improved 0.00000 ======> 0.10508
# [2/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [3/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [4/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# [5/5]
# training loss : 2.303	 training accuracy : 0.101
# validation loss : 2.303	 validation accuracy : 0.105
# test accuracy : 0.101
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# optimizer : Adadelta (
# Parameter Group 0
#     eps: 1e-06
#     lr: 0.01
#     rho: 0.9
#     weight_decay: 0
# )
#  LSTM(
#   (lstm): LSTM(28, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# validation accuracy improved 0.00000 ======> 0.07558
# [2/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [3/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [4/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [5/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# test accuracy : 0.084
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# validation accuracy improved 0.00000 ======> 0.07558
# [2/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [3/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [4/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [5/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# test accuracy : 0.084
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# validation accuracy improved 0.00000 ======> 0.07558
# [2/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [3/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [4/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# [5/5]
# training loss : 2.303	 training accuracy : 0.077
# validation loss : 2.303	 validation accuracy : 0.076
# test accuracy : 0.084
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #3-4 GRU

# %% [markdown]
# ## 3-4-1 hidden layer size

# %%
hidden_layer = [2,5,10]

for item in hidden_layer:
    num_layers = item
    model = GRU(input_size, hidden_size, num_layers, n_outputs, sequence_len)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    loss_function = nn.CrossEntropyLoss()
    
    print("hiddenlayer :", item,"\n",model)
    for i in range(0,3):
        n_epochs = 5
        train_loss = [] # train loss per epoch
        valid_loss = [] # valid loss per epoch
        
        train_acc = [] # train accuracy per epoch
        valid_acc = [] # valid accuracy per epoch
        
        # update following two variables whenever valid accuracy improves
        best_acc = 0
        best_model = copy.deepcopy(model)
        
        for epoch in range(n_epochs):
            model.train() # set model as training mode(for compute gradient)
            train_total = 0
            train_correct = 0
            epoch_train_loss = 0
            for i, data in enumerate(train_loader):
                optimizer.zero_grad()
                
                inputs, labels = data[0], data[1]
                outputs = model(inputs.squeeze(1))
                _, predicted = torch.max(outputs.data, 1)
                train_total += labels.size(0)
                train_correct += (predicted == labels).sum().item()
                
                loss = loss_function(outputs, labels)
                epoch_train_loss += loss.item()
                
                loss.backward() # compute gradient
                optimizer.step() # update weight & bias in the model with computed gradient
                
            train_loss.append(epoch_train_loss/len(train_loader))
            train_acc.append(train_correct/train_total)
            
            model.eval() # set model as evaluation mode
            with torch.no_grad():
                valid_total = 0
                valid_correct = 0
                epoch_valid_loss = 0
                for data in valid_loader:
                    inputs, labels = data[0], data[1]
                    outputs = model(inputs.squeeze(1))
                    
                    _, predicted = torch.max(outputs.data, 1)
                    valid_total += labels.size(0)
                    valid_correct += (predicted == labels).sum().item()
                    
                    loss = loss_function(outputs, labels)
                    epoch_valid_loss += loss.item()
                
                valid_loss.append(epoch_valid_loss/len(valid_loader))
                valid_acc.append(valid_correct / valid_total)
                
            print('[{}/{}]'.format(epoch+1, n_epochs))
            print('training loss : {:.3f}\t training accuracy : {:.3f}'.format(epoch_train_loss/len(train_loader), train_correct/train_total))
            print('validation loss : {:.3f}\t validation accuracy : {:.3f}'.format(epoch_valid_loss/len(valid_loader), valid_correct/valid_total))
            
            if valid_correct/valid_total > best_acc:
                print('validation accuracy improved {:.5f} ======> {:.5f}'.format(best_acc, valid_correct/valid_total))
                best_acc = valid_correct/valid_total
                best_model = copy.deepcopy(model)
        
        best_model.eval()
        with torch.no_grad():
            test_total = 0
            test_correct = 0
            for data in test_loader:
                inputs, labels = data[0], data[1]
                outputs = best_model(inputs.squeeze(1))
                
                _, predicted = torch.max(outputs.data, 1)
                test_total += labels.size(0)
                test_correct += (predicted == labels).sum().item()
                
            test_acc = test_correct / test_total
            print('test accuracy : {:.3f}'.format(test_acc))    
        print("----------------------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# hiddenlayer : 2
#  GRU(
#   (gru): GRU(28, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.265	 training accuracy : 0.930
# validation loss : 0.161	 validation accuracy : 0.960
# validation accuracy improved 0.00000 ======> 0.96000
# [2/5]
# training loss : 0.171	 training accuracy : 0.959
# validation loss : 0.146	 validation accuracy : 0.966
# validation accuracy improved 0.96000 ======> 0.96550
# [3/5]
# training loss : 0.356	 training accuracy : 0.928
# validation loss : 0.262	 validation accuracy : 0.939
# [4/5]
# training loss : 0.206	 training accuracy : 0.951
# validation loss : 0.206	 validation accuracy : 0.948
# [5/5]
# training loss : 0.221	 training accuracy : 0.946
# validation loss : 0.195	 validation accuracy : 0.953
# test accuracy : 0.966
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.218	 training accuracy : 0.947
# validation loss : 0.403	 validation accuracy : 0.913
# validation accuracy improved 0.00000 ======> 0.91283
# [2/5]
# training loss : 0.263	 training accuracy : 0.936
# validation loss : 0.179	 validation accuracy : 0.951
# validation accuracy improved 0.91283 ======> 0.95092
# [3/5]
# training loss : 0.157	 training accuracy : 0.959
# validation loss : 0.152	 validation accuracy : 0.962
# validation accuracy improved 0.95092 ======> 0.96150
# [4/5]
# training loss : 0.184	 training accuracy : 0.952
# validation loss : 0.154	 validation accuracy : 0.961
# [5/5]
# training loss : 0.189	 training accuracy : 0.953
# validation loss : 0.199	 validation accuracy : 0.950
# test accuracy : 0.959
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.175	 training accuracy : 0.956
# validation loss : 0.139	 validation accuracy : 0.961
# validation accuracy improved 0.00000 ======> 0.96083
# [2/5]
# training loss : 0.154	 training accuracy : 0.960
# validation loss : 0.181	 validation accuracy : 0.957
# [3/5]
# training loss : 0.141	 training accuracy : 0.963
# validation loss : 0.133	 validation accuracy : 0.965
# validation accuracy improved 0.96083 ======> 0.96542
# [4/5]
# training loss : 0.171	 training accuracy : 0.956
# validation loss : 0.189	 validation accuracy : 0.954
# [5/5]
# training loss : 0.159	 training accuracy : 0.960
# validation loss : 0.175	 validation accuracy : 0.958
# test accuracy : 0.964
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# hiddenlayer : 5
#  GRU(
#   (gru): GRU(28, 64, num_layers=5, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.350	 training accuracy : 0.895
# validation loss : 0.181	 validation accuracy : 0.944
# validation accuracy improved 0.00000 ======> 0.94442
# [2/5]
# training loss : 0.229	 training accuracy : 0.930
# validation loss : 0.213	 validation accuracy : 0.934
# [3/5]
# training loss : 0.241	 training accuracy : 0.926
# validation loss : 0.256	 validation accuracy : 0.924
# [4/5]
# training loss : 0.198	 training accuracy : 0.939
# validation loss : 0.192	 validation accuracy : 0.940
# [5/5]
# training loss : 0.202	 training accuracy : 0.938
# validation loss : 0.201	 validation accuracy : 0.938
# test accuracy : 0.948
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.265	 training accuracy : 0.918
# validation loss : 0.202	 validation accuracy : 0.935
# validation accuracy improved 0.00000 ======> 0.93517
# [2/5]
# training loss : 0.183	 training accuracy : 0.943
# validation loss : 0.200	 validation accuracy : 0.936
# validation accuracy improved 0.93517 ======> 0.93625
# [3/5]
# training loss : 0.203	 training accuracy : 0.937
# validation loss : 0.185	 validation accuracy : 0.941
# validation accuracy improved 0.93625 ======> 0.94067
# [4/5]
# training loss : 0.239	 training accuracy : 0.927
# validation loss : 0.194	 validation accuracy : 0.938
# [5/5]
# training loss : 0.261	 training accuracy : 0.919
# validation loss : 0.238	 validation accuracy : 0.926
# test accuracy : 0.941
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.641	 training accuracy : 0.802
# validation loss : 0.365	 validation accuracy : 0.888
# validation accuracy improved 0.00000 ======> 0.88767
# [2/5]
# training loss : 0.298	 training accuracy : 0.908
# validation loss : 0.236	 validation accuracy : 0.926
# validation accuracy improved 0.88767 ======> 0.92633
# [3/5]
# training loss : 0.555	 training accuracy : 0.835
# validation loss : 0.447	 validation accuracy : 0.864
# [4/5]
# training loss : 0.383	 training accuracy : 0.881
# validation loss : 0.287	 validation accuracy : 0.913
# [5/5]
# training loss : 0.299	 training accuracy : 0.908
# validation loss : 0.292	 validation accuracy : 0.909
# test accuracy : 0.927
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# hiddenlayer : 10
#  GRU(
#   (gru): GRU(28, 64, num_layers=10, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 1.209	 training accuracy : 0.578
# validation loss : 0.762	 validation accuracy : 0.758
# validation accuracy improved 0.00000 ======> 0.75833
# [2/5]
# training loss : 0.751	 training accuracy : 0.746
# validation loss : 0.627	 validation accuracy : 0.788
# validation accuracy improved 0.75833 ======> 0.78792
# [3/5]
# training loss : 0.814	 training accuracy : 0.724
# validation loss : 0.771	 validation accuracy : 0.746
# [4/5]
# training loss : 0.883	 training accuracy : 0.691
# validation loss : 0.908	 validation accuracy : 0.699
# [5/5]
# training loss : 0.849	 training accuracy : 0.698
# validation loss : 2.926	 validation accuracy : 0.182
# test accuracy : 0.784
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.822	 training accuracy : 0.704
# validation loss : 0.797	 validation accuracy : 0.714
# validation accuracy improved 0.00000 ======> 0.71433
# [2/5]
# training loss : 1.431	 training accuracy : 0.472
# validation loss : 2.313	 validation accuracy : 0.101
# [3/5]
# training loss : 1.644	 training accuracy : 0.387
# validation loss : 2.312	 validation accuracy : 0.115
# [4/5]
# training loss : 2.308	 training accuracy : 0.103
# validation loss : 2.305	 validation accuracy : 0.099
# [5/5]
# training loss : 2.305	 training accuracy : 0.105
# validation loss : 2.302	 validation accuracy : 0.115
# test accuracy : 0.706
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.302	 training accuracy : 0.110
# validation loss : 2.302	 validation accuracy : 0.115
# validation accuracy improved 0.00000 ======> 0.11475
# [2/5]
# training loss : 2.304	 training accuracy : 0.106
# validation loss : 2.301	 validation accuracy : 0.115
# [3/5]
# training loss : 2.303	 training accuracy : 0.107
# validation loss : 2.305	 validation accuracy : 0.101
# [4/5]
# training loss : 2.303	 training accuracy : 0.108
# validation loss : 2.302	 validation accuracy : 0.115
# [5/5]
# training loss : 2.303	 training accuracy : 0.106
# validation loss : 2.302	 validation accuracy : 0.115
# test accuracy : 0.114
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3-4-2 Optimization

# %%
optimizer_list= [torch.optim.Adagrad(model.parameters(), lr = learning_rate),
                 torch.optim.RMSprop(model.parameters(), lr = learning_rate),
                 torch.optim.Adadelta(model.parameters(), lr = learning_rate)]

for item in optimizer_list:
    num_layers = 2
    model = GRU(input_size, hidden_size, num_layers, n_outputs, sequence_len)
    optimizer = item
    loss_function = nn.CrossEntropyLoss()
    
    print("optimizer :", item,"\n",model)
    for i in range(0,3):
        n_epochs = 5
        train_loss = [] # train loss per epoch
        valid_loss = [] # valid loss per epoch
        
        train_acc = [] # train accuracy per epoch
        valid_acc = [] # valid accuracy per epoch
        
        # update following two variables whenever valid accuracy improves
        best_acc = 0
        best_model = copy.deepcopy(model)
        
        for epoch in range(n_epochs):
            model.train() # set model as training mode(for compute gradient)
            train_total = 0
            train_correct = 0
            epoch_train_loss = 0
            for i, data in enumerate(train_loader):
                optimizer.zero_grad()
                
                inputs, labels = data[0], data[1]
                outputs = model(inputs.squeeze(1))
                _, predicted = torch.max(outputs.data, 1)
                train_total += labels.size(0)
                train_correct += (predicted == labels).sum().item()
                
                loss = loss_function(outputs, labels)
                epoch_train_loss += loss.item()
                
                loss.backward() # compute gradient
                optimizer.step() # update weight & bias in the model with computed gradient
                
            train_loss.append(epoch_train_loss/len(train_loader))
            train_acc.append(train_correct/train_total)
            
            model.eval() # set model as evaluation mode
            with torch.no_grad():
                valid_total = 0
                valid_correct = 0
                epoch_valid_loss = 0
                for data in valid_loader:
                    inputs, labels = data[0], data[1]
                    outputs = model(inputs.squeeze(1))
                    
                    _, predicted = torch.max(outputs.data, 1)
                    valid_total += labels.size(0)
                    valid_correct += (predicted == labels).sum().item()
                    
                    loss = loss_function(outputs, labels)
                    epoch_valid_loss += loss.item()
                
                valid_loss.append(epoch_valid_loss/len(valid_loader))
                valid_acc.append(valid_correct / valid_total)
                
            print('[{}/{}]'.format(epoch+1, n_epochs))
            print('training loss : {:.3f}\t training accuracy : {:.3f}'.format(epoch_train_loss/len(train_loader), train_correct/train_total))
            print('validation loss : {:.3f}\t validation accuracy : {:.3f}'.format(epoch_valid_loss/len(valid_loader), valid_correct/valid_total))
            
            if valid_correct/valid_total > best_acc:
                print('validation accuracy improved {:.5f} ======> {:.5f}'.format(best_acc, valid_correct/valid_total))
                best_acc = valid_correct/valid_total
                best_model = copy.deepcopy(model)
        
        best_model.eval()
        with torch.no_grad():
            test_total = 0
            test_correct = 0
            for data in test_loader:
                inputs, labels = data[0], data[1]
                outputs = best_model(inputs.squeeze(1))
                
                _, predicted = torch.max(outputs.data, 1)
                test_total += labels.size(0)
                test_correct += (predicted == labels).sum().item()
                
            test_acc = test_correct / test_total
            print('test accuracy : {:.3f}'.format(test_acc))    
        print("----------------------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# optimizer : Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.01
#     lr_decay: 0
#     weight_decay: 0
# )
#  GRU(
#   (gru): GRU(28, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# validation accuracy improved 0.00000 ======> 0.11075
# [2/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [3/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [4/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [5/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# test accuracy : 0.114
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# validation accuracy improved 0.00000 ======> 0.11075
# [2/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [3/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [4/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [5/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# test accuracy : 0.114
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# validation accuracy improved 0.00000 ======> 0.11075
# [2/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [3/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [4/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# [5/5]
# training loss : 2.306	 training accuracy : 0.112
# validation loss : 2.305	 validation accuracy : 0.111
# test accuracy : 0.114
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# optimizer : RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 0.01
#     momentum: 0
#     weight_decay: 0
# )
#  GRU(
#   (gru): GRU(28, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# validation accuracy improved 0.00000 ======> 0.11942
# [2/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [3/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [4/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [5/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# test accuracy : 0.124
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# validation accuracy improved 0.00000 ======> 0.11942
# [2/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [3/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [4/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [5/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# test accuracy : 0.124
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# validation accuracy improved 0.00000 ======> 0.11942
# [2/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [3/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [4/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# [5/5]
# training loss : 2.304	 training accuracy : 0.119
# validation loss : 2.304	 validation accuracy : 0.119
# test accuracy : 0.124
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# optimizer : Adadelta (
# Parameter Group 0
#     eps: 1e-06
#     lr: 0.01
#     rho: 0.9
#     weight_decay: 0
# )
#  GRU(
#   (gru): GRU(28, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# validation accuracy improved 0.00000 ======> 0.04842
# [2/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [3/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [4/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [5/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# test accuracy : 0.043
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# validation accuracy improved 0.00000 ======> 0.04842
# [2/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [3/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [4/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [5/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# test accuracy : 0.043
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# validation accuracy improved 0.00000 ======> 0.04842
# [2/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [3/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [4/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# [5/5]
# training loss : 2.306	 training accuracy : 0.046
# validation loss : 2.306	 validation accuracy : 0.048
# test accuracy : 0.043
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #3-5 Change parameter(bias)

# %%
class LSTM_bias(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, n_outputs, sequence_len):
        super(LSTM_bias, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True,bias= False)
        self.fc = nn.Linear(hidden_size * sequence_len, n_outputs)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        x, _ = self.lstm(x, (h0, c0))
        x = x.reshape(x.shape[0], -1)
        x = self.fc(x)

        return x

# %%
#bias parameter가 False인 모델의 layer 수를 바꿔가며 비교

hidden_layer = [2,5,10]

for item in hidden_layer:
    num_layers = item
    model = LSTM_bias(input_size, hidden_size, num_layers, n_outputs, sequence_len)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    loss_function = nn.CrossEntropyLoss()

    print("hiddenlayer :", item,"\n",model)
    for i in range(0,3):
        n_epochs = 5
        train_loss = [] # train loss per epoch
        valid_loss = [] # valid loss per epoch
        
        train_acc = [] # train accuracy per epoch
        valid_acc = [] # valid accuracy per epoch
        
        # update following two variables whenever valid accuracy improves
        best_acc = 0
        best_model = copy.deepcopy(model)
        
        for epoch in range(n_epochs):
            model.train() # set model as training mode(for compute gradient)
            train_total = 0
            train_correct = 0
            epoch_train_loss = 0
            for i, data in enumerate(train_loader):
                optimizer.zero_grad()
                
                inputs, labels = data[0], data[1]
                outputs = model(inputs.squeeze(1))
                _, predicted = torch.max(outputs.data, 1)
                train_total += labels.size(0)
                train_correct += (predicted == labels).sum().item()
                
                loss = loss_function(outputs, labels)
                epoch_train_loss += loss.item()
                
                loss.backward() # compute gradient
                optimizer.step() # update weight & bias in the model with computed gradient
                
            train_loss.append(epoch_train_loss/len(train_loader))
            train_acc.append(train_correct/train_total)
            
            model.eval() # set model as evaluation mode
            with torch.no_grad():
                valid_total = 0
                valid_correct = 0
                epoch_valid_loss = 0
                for data in valid_loader:
                    inputs, labels = data[0], data[1]
                    outputs = model(inputs.squeeze(1))
                    
                    _, predicted = torch.max(outputs.data, 1)
                    valid_total += labels.size(0)
                    valid_correct += (predicted == labels).sum().item()
                    
                    loss = loss_function(outputs, labels)
                    epoch_valid_loss += loss.item()
                
                valid_loss.append(epoch_valid_loss/len(valid_loader))
                valid_acc.append(valid_correct / valid_total)
                
            print('[{}/{}]'.format(epoch+1, n_epochs))
            print('training loss : {:.3f}\t training accuracy : {:.3f}'.format(epoch_train_loss/len(train_loader), train_correct/train_total))
            print('validation loss : {:.3f}\t validation accuracy : {:.3f}'.format(epoch_valid_loss/len(valid_loader), valid_correct/valid_total))
            
            if valid_correct/valid_total > best_acc:
                print('validation accuracy improved {:.5f} ======> {:.5f}'.format(best_acc, valid_correct/valid_total))
                best_acc = valid_correct/valid_total
                best_model = copy.deepcopy(model)
        
        best_model.eval()
        with torch.no_grad():
            test_total = 0
            test_correct = 0
            for data in test_loader:
                inputs, labels = data[0], data[1]
                outputs = best_model(inputs.squeeze(1))
                
                _, predicted = torch.max(outputs.data, 1)
                test_total += labels.size(0)
                test_correct += (predicted == labels).sum().item()
                
            test_acc = test_correct / test_total
            print('test accuracy : {:.3f}'.format(test_acc))    
        print("----------------------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# hiddenlayer : 2
#  LSTM_bias(
#   (lstm): LSTM(28, 64, num_layers=2, bias=False, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.183	 training accuracy : 0.943
# validation loss : 0.076	 validation accuracy : 0.978
# validation accuracy improved 0.00000 ======> 0.97783
# [2/5]
# training loss : 0.075	 training accuracy : 0.978
# validation loss : 0.061	 validation accuracy : 0.981
# validation accuracy improved 0.97783 ======> 0.98133
# [3/5]
# training loss : 0.059	 training accuracy : 0.983
# validation loss : 0.056	 validation accuracy : 0.984
# validation accuracy improved 0.98133 ======> 0.98375
# [4/5]
# training loss : 0.048	 training accuracy : 0.985
# validation loss : 0.064	 validation accuracy : 0.983
# [5/5]
# training loss : 0.039	 training accuracy : 0.987
# validation loss : 0.072	 validation accuracy : 0.981
# test accuracy : 0.983
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.034	 training accuracy : 0.989
# validation loss : 0.053	 validation accuracy : 0.985
# validation accuracy improved 0.00000 ======> 0.98533
# [2/5]
# training loss : 0.031	 training accuracy : 0.990
# validation loss : 0.060	 validation accuracy : 0.985
# [3/5]
# training loss : 0.026	 training accuracy : 0.991
# validation loss : 0.072	 validation accuracy : 0.983
# [4/5]
# training loss : 0.024	 training accuracy : 0.992
# validation loss : 0.065	 validation accuracy : 0.985
# [5/5]
# training loss : 0.023	 training accuracy : 0.993
# validation loss : 0.072	 validation accuracy : 0.983
# test accuracy : 0.984
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.022	 training accuracy : 0.993
# validation loss : 0.065	 validation accuracy : 0.985
# validation accuracy improved 0.00000 ======> 0.98525
# [2/5]
# training loss : 0.020	 training accuracy : 0.994
# validation loss : 0.078	 validation accuracy : 0.982
# [3/5]
# training loss : 0.016	 training accuracy : 0.995
# validation loss : 0.072	 validation accuracy : 0.984
# [4/5]
# training loss : 0.020	 training accuracy : 0.993
# validation loss : 0.073	 validation accuracy : 0.984
# [5/5]
# training loss : 0.016	 training accuracy : 0.995
# validation loss : 0.083	 validation accuracy : 0.983
# test accuracy : 0.984
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# hiddenlayer : 5
#  LSTM_bias(
#   (lstm): LSTM(28, 64, num_layers=5, bias=False, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.283	 training accuracy : 0.909
# validation loss : 0.097	 validation accuracy : 0.969
# validation accuracy improved 0.00000 ======> 0.96908
# [2/5]
# training loss : 0.102	 training accuracy : 0.969
# validation loss : 0.080	 validation accuracy : 0.975
# validation accuracy improved 0.96908 ======> 0.97458
# [3/5]
# training loss : 0.080	 training accuracy : 0.975
# validation loss : 0.067	 validation accuracy : 0.980
# validation accuracy improved 0.97458 ======> 0.98000
# [4/5]
# training loss : 0.068	 training accuracy : 0.979
# validation loss : 0.052	 validation accuracy : 0.985
# validation accuracy improved 0.98000 ======> 0.98467
# [5/5]
# training loss : 0.058	 training accuracy : 0.982
# validation loss : 0.068	 validation accuracy : 0.979
# test accuracy : 0.985
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.047	 training accuracy : 0.986
# validation loss : 0.060	 validation accuracy : 0.983
# validation accuracy improved 0.00000 ======> 0.98283
# [2/5]
# training loss : 0.045	 training accuracy : 0.986
# validation loss : 0.062	 validation accuracy : 0.982
# [3/5]
# training loss : 0.041	 training accuracy : 0.987
# validation loss : 0.078	 validation accuracy : 0.976
# [4/5]
# training loss : 0.041	 training accuracy : 0.987
# validation loss : 0.060	 validation accuracy : 0.981
# [5/5]
# training loss : 0.039	 training accuracy : 0.988
# validation loss : 0.047	 validation accuracy : 0.986
# validation accuracy improved 0.98283 ======> 0.98567
# test accuracy : 0.985
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.031	 training accuracy : 0.989
# validation loss : 0.049	 validation accuracy : 0.986
# validation accuracy improved 0.00000 ======> 0.98567
# [2/5]
# training loss : 0.031	 training accuracy : 0.990
# validation loss : 0.059	 validation accuracy : 0.985
# [3/5]
# training loss : 0.031	 training accuracy : 0.990
# validation loss : 0.059	 validation accuracy : 0.984
# [4/5]
# training loss : 0.026	 training accuracy : 0.992
# validation loss : 0.061	 validation accuracy : 0.984
# [5/5]
# training loss : 0.026	 training accuracy : 0.992
# validation loss : 0.052	 validation accuracy : 0.985
# test accuracy : 0.986
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# hiddenlayer : 10
#  LSTM_bias(
#   (lstm): LSTM(28, 64, num_layers=10, bias=False, batch_first=True)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.400	 training accuracy : 0.870
# validation loss : 0.137	 validation accuracy : 0.957
# validation accuracy improved 0.00000 ======> 0.95700
# [2/5]
# training loss : 0.130	 training accuracy : 0.962
# validation loss : 0.118	 validation accuracy : 0.966
# validation accuracy improved 0.95700 ======> 0.96592
# [3/5]
# training loss : 0.102	 training accuracy : 0.969
# validation loss : 0.098	 validation accuracy : 0.970
# validation accuracy improved 0.96592 ======> 0.97000
# [4/5]
# training loss : 0.164	 training accuracy : 0.950
# validation loss : 0.091	 validation accuracy : 0.972
# validation accuracy improved 0.97000 ======> 0.97192
# [5/5]
# training loss : 0.103	 training accuracy : 0.969
# validation loss : 0.119	 validation accuracy : 0.967
# test accuracy : 0.969
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.140	 training accuracy : 0.956
# validation loss : 0.126	 validation accuracy : 0.961
# validation accuracy improved 0.00000 ======> 0.96075
# [2/5]
# training loss : 0.144	 training accuracy : 0.956
# validation loss : 0.145	 validation accuracy : 0.957
# [3/5]
# training loss : 0.145	 training accuracy : 0.955
# validation loss : 0.111	 validation accuracy : 0.966
# validation accuracy improved 0.96075 ======> 0.96592
# [4/5]
# training loss : 0.100	 training accuracy : 0.969
# validation loss : 0.095	 validation accuracy : 0.972
# validation accuracy improved 0.96592 ======> 0.97167
# [5/5]
# training loss : 0.084	 training accuracy : 0.975
# validation loss : 0.090	 validation accuracy : 0.973
# validation accuracy improved 0.97167 ======> 0.97317
# test accuracy : 0.971
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# [1/5]
# training loss : 0.085	 training accuracy : 0.974
# validation loss : 0.097	 validation accuracy : 0.972
# validation accuracy improved 0.00000 ======> 0.97175
# [2/5]
# training loss : 0.082	 training accuracy : 0.975
# validation loss : 0.086	 validation accuracy : 0.974
# validation accuracy improved 0.97175 ======> 0.97383
# [3/5]
# training loss : 0.082	 training accuracy : 0.974
# validation loss : 0.088	 validation accuracy : 0.974
# validation accuracy improved 0.97383 ======> 0.97417
# [4/5]
# training loss : 0.078	 training accuracy : 0.976
# validation loss : 0.095	 validation accuracy : 0.972
# [5/5]
# training loss : 0.080	 training accuracy : 0.975
# validation loss : 0.092	 validation accuracy : 0.973
# test accuracy : 0.973
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #3-6 Compare accuracy of RNN/CNN

# %% [markdown]
# #3-7 L2 (ridge) regularization

# %%
input_size = 28
sequence_len = 28
num_layers = 2
hidden_size = 64
n_outputs = 10

learning_rate = 0.01

model = LSTM(input_size, hidden_size, num_layers, n_outputs, sequence_len)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate, weight_decay= 1e-5)
loss_function = nn.CrossEntropyLoss()

# %%
n_epochs = 5

train_loss = [] # train loss per epoch
valid_loss = [] # valid loss per epoch

train_acc = [] # train accuracy per epoch
valid_acc = [] # valid accuracy per epoch

# update following two variables whenever valid accuracy improves
best_acc = 0
best_model = copy.deepcopy(model)

for epoch in range(n_epochs):
    model.train() # set model as training mode(for compute gradient)
    train_total = 0
    train_correct = 0
    epoch_train_loss = 0
    for i, data in enumerate(train_loader):
        # In PyTorch, for every mini-batch during the training phase, we have to explicitly
        # set the gradients to zero before starting to do backpropragation with following code
        optimizer.zero_grad()

        inputs, labels = data[0], data[1]
        outputs = model(inputs.squeeze(1))
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        loss = loss_function(outputs, labels)
        epoch_train_loss += loss.item()

        loss.backward() # compute gradient
        optimizer.step() # update weight & bias in the model with computed gradient

    train_loss.append(epoch_train_loss/len(train_loader))
    train_acc.append(train_correct/train_total)

    model.eval() # set model as evaluation mode
    with torch.no_grad():# we don't need to compute gradient during the evaluation process
        valid_total = 0
        valid_correct = 0
        epoch_valid_loss = 0
        for data in valid_loader:
            inputs, labels = data[0], data[1]
            outputs = model(inputs.squeeze(1))

            _, predicted = torch.max(outputs.data, 1)
            valid_total += labels.size(0)
            valid_correct += (predicted == labels).sum().item()

            loss = loss_function(outputs, labels)
            epoch_valid_loss += loss.item()

        valid_loss.append(epoch_valid_loss/len(valid_loader))
        valid_acc.append(valid_correct / valid_total)

    print('[{}/{}]'.format(epoch+1, n_epochs))
    print('training loss : {:.3f}\t training accuracy : {:.3f}'.format(epoch_train_loss/len(train_loader), train_correct/train_total))
    print('validation loss : {:.3f}\t validation accuracy : {:.3f}'.format(epoch_valid_loss/len(valid_loader), valid_correct/valid_total))

    if valid_correct/valid_total > best_acc:
        print('validation accuracy improved {:.5f} ======> {:.5f}'.format(best_acc, valid_correct/valid_total))
        best_acc = valid_correct/valid_total
        best_model = copy.deepcopy(model)
# Out:
# [1/5]
# training loss : 0.177	 training accuracy : 0.945
# validation loss : 0.075	 validation accuracy : 0.977
# validation accuracy improved 0.00000 ======> 0.97692
# [2/5]
# training loss : 0.075	 training accuracy : 0.977
# validation loss : 0.068	 validation accuracy : 0.979
# validation accuracy improved 0.97692 ======> 0.97942
# [3/5]
# training loss : 0.064	 training accuracy : 0.980
# validation loss : 0.063	 validation accuracy : 0.979
# [4/5]
# training loss : 0.056	 training accuracy : 0.983
# validation loss : 0.058	 validation accuracy : 0.982
# validation accuracy improved 0.97942 ======> 0.98167
# [5/5]
# training loss : 0.052	 training accuracy : 0.984
# validation loss : 0.099	 validation accuracy : 0.970

# %% [markdown]
# # 3-8 Add Dropout

# %%
class LSTM_DR(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, n_outputs, sequence_len, drop_prop):
        super(LSTM_DR, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True,dropout = drop_prop)
        self.fc = nn.Linear(hidden_size * sequence_len, n_outputs)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        x, _ = self.lstm(x, (h0, c0))
        x = x.reshape(x.shape[0], -1)
        x = self.fc(x)

        return x

# %%
prop = [0.1,0.2,0.3]
train_loss = [] # train loss per epoch
valid_loss = [] # valid loss per epoch
        
train_acc = [] # train accuracy per epoch
valid_acc = [] # valid accuracy per epoch

for item in prop:
    drop_prop = item
    model = LSTM_DR(input_size, hidden_size, num_layers, n_outputs, sequence_len, drop_prop)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    loss_function = nn.CrossEntropyLoss()
    
    print("Dropout property :", item,"\n",model)
    
    n_epochs = 5
    best_acc = 0
    best_model = copy.deepcopy(model)
        
    for epoch in range(n_epochs):
        model.train() # set model as training mode(for compute gradient)
        train_total = 0
        train_correct = 0
        epoch_train_loss = 0
        for i, data in enumerate(train_loader):
            optimizer.zero_grad()
                
            inputs, labels = data[0], data[1]
            outputs = model(inputs.squeeze(1))
            _, predicted = torch.max(outputs.data, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()
                
            loss = loss_function(outputs, labels)
            epoch_train_loss += loss.item()
                
            loss.backward() # compute gradient
            optimizer.step() # update weight & bias in the model with computed gradient
                
        train_loss.append(epoch_train_loss/len(train_loader))
        train_acc.append(train_correct/train_total)
            
        model.eval() # set model as evaluation mode
        with torch.no_grad():
            valid_total = 0
            valid_correct = 0
            epoch_valid_loss = 0
            for data in valid_loader:
                inputs, labels = data[0], data[1]
                outputs = model(inputs.squeeze(1))
                    
                _, predicted = torch.max(outputs.data, 1)
                valid_total += labels.size(0)
                valid_correct += (predicted == labels).sum().item()
                    
                loss = loss_function(outputs, labels)
                epoch_valid_loss += loss.item()
                
            valid_loss.append(epoch_valid_loss/len(valid_loader))
            valid_acc.append(valid_correct / valid_total)
                
        print('[{}/{}]'.format(epoch+1, n_epochs))
        print('training loss : {:.3f}\t training accuracy : {:.3f}'.format(epoch_train_loss/len(train_loader), train_correct/train_total))
        print('validation loss : {:.3f}\t validation accuracy : {:.3f}'.format(epoch_valid_loss/len(valid_loader), valid_correct/valid_total))
            
        if valid_correct/valid_total > best_acc:
            print('validation accuracy improved {:.5f} ======> {:.5f}'.format(best_acc, valid_correct/valid_total))
            best_acc = valid_correct/valid_total
            best_model = copy.deepcopy(model)
        
    best_model.eval()
    with torch.no_grad():
        test_total = 0
        test_correct = 0
        for data in test_loader:
            inputs, labels = data[0], data[1]
            outputs = best_model(inputs.squeeze(1))
                
            _, predicted = torch.max(outputs.data, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()
                
        test_acc = test_correct / test_total
        print('test accuracy : {:.3f}'.format(test_acc))
# Out:
# Dropout property : 0.1
#  LSTM_DR(
#   (lstm): LSTM(28, 64, num_layers=2, batch_first=True, dropout=0.1)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.175	 training accuracy : 0.946
# validation loss : 0.096	 validation accuracy : 0.973
# validation accuracy improved 0.00000 ======> 0.97292
# [2/5]
# training loss : 0.080	 training accuracy : 0.974
# validation loss : 0.070	 validation accuracy : 0.978
# validation accuracy improved 0.97292 ======> 0.97750
# [3/5]
# training loss : 0.065	 training accuracy : 0.980
# validation loss : 0.073	 validation accuracy : 0.977
# [4/5]
# training loss : 0.058	 training accuracy : 0.982
# validation loss : 0.062	 validation accuracy : 0.981
# validation accuracy improved 0.97750 ======> 0.98142
# [5/5]
# training loss : 0.050	 training accuracy : 0.984
# validation loss : 0.066	 validation accuracy : 0.980
# test accuracy : 0.981
# Dropout property : 0.2
#  LSTM_DR(
#   (lstm): LSTM(28, 64, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.181	 training accuracy : 0.943
# validation loss : 0.070	 validation accuracy : 0.979
# validation accuracy improved 0.00000 ======> 0.97850
# [2/5]
# training loss : 0.084	 training accuracy : 0.974
# validation loss : 0.064	 validation accuracy : 0.979
# validation accuracy improved 0.97850 ======> 0.97933
# [3/5]
# training loss : 0.066	 training accuracy : 0.980
# validation loss : 0.060	 validation accuracy : 0.980
# validation accuracy improved 0.97933 ======> 0.97992
# [4/5]
# training loss : 0.058	 training accuracy : 0.982
# validation loss : 0.066	 validation accuracy : 0.980
# [5/5]
# training loss : 0.054	 training accuracy : 0.983
# validation loss : 0.060	 validation accuracy : 0.982
# validation accuracy improved 0.97992 ======> 0.98233
# test accuracy : 0.982
# Dropout property : 0.3
#  LSTM_DR(
#   (lstm): LSTM(28, 64, num_layers=2, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=1792, out_features=10, bias=True)
# )
# [1/5]
# training loss : 0.184	 training accuracy : 0.943
# validation loss : 0.075	 validation accuracy : 0.977
# validation accuracy improved 0.00000 ======> 0.97725
# [2/5]
# training loss : 0.086	 training accuracy : 0.972
# validation loss : 0.068	 validation accuracy : 0.979
# validation accuracy improved 0.97725 ======> 0.97942
# [3/5]
# training loss : 0.072	 training accuracy : 0.978
# validation loss : 0.066	 validation accuracy : 0.981
# validation accuracy improved 0.97942 ======> 0.98067
# [4/5]
# training loss : 0.062	 training accuracy : 0.981
# validation loss : 0.058	 validation accuracy : 0.982
# validation accuracy improved 0.98067 ======> 0.98217
# [5/5]
# training loss : 0.057	 training accuracy : 0.982
# validation loss : 0.062	 validation accuracy : 0.981
# test accuracy : 0.982

# %% [markdown]
# #3-9 Save checkpoint

# %% [markdown]
# ## Dropout = 0.25인 LSTM을 save

# %%
import os

def save_model(path, model, optimizer, epoch, loss):

    torch.save({
        'epoch' : epoch,
        'model_state_dict' : model.state_dict(),
        'optimizer_state_dict' : optimizer.state_dict(),
        'loss' : loss
    }, os.path.join(path, 'cnn_model.pt'))
    print('model saved, {}'.format(os.path.join(path, 'LSTM_model.pt')))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_dir = '/content/drive/MyDrive/ColabNotebooks/2022_ML_hw4'

train_loss = [] # train loss per epoch
valid_loss = [] # valid loss per epoch
        
train_acc = [] # train accuracy per epoch
valid_acc = [] # valid accuracy per epoch


model = LSTM_DR(input_size, hidden_size, num_layers, n_outputs, sequence_len, 0.25)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
loss_function = nn.CrossEntropyLoss()
    
n_epochs = 5
   
best_acc = 0
best_model = copy.deepcopy(model)
        
for epoch in range(n_epochs):
    model.train() # set model as training mode(for compute gradient)
    train_total = 0
    train_correct = 0
    epoch_train_loss = 0
    for i, data in enumerate(train_loader):
        optimizer.zero_grad()
                
        inputs, labels = data[0], data[1]
        outputs = model(inputs.squeeze(1))
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()
                
        loss = loss_function(outputs, labels)
        epoch_train_loss += loss.item()
                
        loss.backward() # compute gradient
        optimizer.step() # update weight & bias in the model with computed gradient
                
    train_loss.append(epoch_train_loss/len(train_loader))
    train_acc.append(train_correct/train_total)
            
    model.eval() # set model as evaluation mode
    with torch.no_grad():
        valid_total = 0
        valid_correct = 0
        epoch_valid_loss = 0
        for data in valid_loader:
            inputs, labels = data[0], data[1]
            outputs = model(inputs.squeeze(1))
                    
            _, predicted = torch.max(outputs.data, 1)
            valid_total += labels.size(0)
            valid_correct += (predicted == labels).sum().item()
                    
            loss = loss_function(outputs, labels)
            epoch_valid_loss += loss.item()
                
        valid_loss.append(epoch_valid_loss/len(valid_loader))
        valid_acc.append(valid_correct / valid_total)
                
    print('[{}/{}]'.format(epoch+1, n_epochs))
    print('training loss : {:.3f}\t training accuracy : {:.3f}'.format(epoch_train_loss/len(train_loader), train_correct/train_total))
    print('validation loss : {:.3f}\t validation accuracy : {:.3f}'.format(epoch_valid_loss/len(valid_loader), valid_correct/valid_total))
            
    if valid_correct/valid_total > best_acc:
        print('validation accuracy improved {:.5f} ======> {:.5f}'.format(best_acc, valid_correct/valid_total))
        best_acc = valid_correct/valid_total
        best_model = copy.deepcopy(model)
        save_model(save_dir, model, optimizer, epoch, epoch_train_loss)
# Out:
# [1/5]
# training loss : 0.186	 training accuracy : 0.942
# validation loss : 0.071	 validation accuracy : 0.979
# validation accuracy improved 0.00000 ======> 0.97900
# model saved, /content/drive/MyDrive/ColabNotebooks/2022_ML_hw4/cnn_model.pt
# [2/5]
# training loss : 0.086	 training accuracy : 0.974
# validation loss : 0.067	 validation accuracy : 0.981
# validation accuracy improved 0.97900 ======> 0.98067
# model saved, /content/drive/MyDrive/ColabNotebooks/2022_ML_hw4/cnn_model.pt
# [3/5]
# training loss : 0.070	 training accuracy : 0.978
# validation loss : 0.059	 validation accuracy : 0.982
# validation accuracy improved 0.98067 ======> 0.98233
# model saved, /content/drive/MyDrive/ColabNotebooks/2022_ML_hw4/cnn_model.pt
# [4/5]
# training loss : 0.063	 training accuracy : 0.980
# validation loss : 0.060	 validation accuracy : 0.981
# [5/5]
# training loss : 0.061	 training accuracy : 0.981
# validation loss : 0.048	 validation accuracy : 0.984
# validation accuracy improved 0.98233 ======> 0.98358
# model saved, /content/drive/MyDrive/ColabNotebooks/2022_ML_hw4/cnn_model.pt

# %%
best_model.eval()
with torch.no_grad():
    test_total = 0
    test_correct = 0
    for data in test_loader:
        inputs, labels = data[0], data[1]
        outputs = best_model(inputs.squeeze(1))
                
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()
                
    test_acc = test_correct / test_total
    print('test accuracy : {:.3f}'.format(test_acc))
# Out:
# test accuracy : 0.983

# %%
loaded_model = LSTM_DR(input_size, hidden_size, num_layers, n_outputs, sequence_len, 0.25)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

checkpoint = torch.load(os.path.join(save_dir, 'LSTM_model.pt'))
loaded_model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print('model successfully loaded!')

loaded_model.eval()
with torch.no_grad():
    test_total = 0
    test_correct = 0
    for data in test_loader:
        inputs, labels = data[0], data[1]
        outputs = loaded_model(inputs.squeeze(1))

        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

    test_acc = test_correct / test_total
    print('test accuracy : {:.3f}'.format(test_acc))
# Out:
# model successfully loaded!
# test accuracy : 0.983
